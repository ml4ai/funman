# %%
import asyncio
import nest_asyncio
import os
import json
import unittest
from pathlib import Path

import funman.api.client as client
from funman.api.api import app
from funman.api.server import Server, ServerConfig

API_BASE_PATH = os.path.join(os.getcwd(), "..")
API_SERVER_HOST = "0.0.0.0"
API_SERVER_PORT = 8190
SERVER_URL = f"http://{API_SERVER_HOST}:{API_SERVER_PORT}"
OPENAPI_URL = f"{SERVER_URL}/openapi.json"
CLIENT_NAME = "funman-api-client"

# %%
# Start API Server
server = Server(
            config=ServerConfig(
                app,
                host=API_SERVER_HOST,
                port=API_SERVER_PORT,
                log_level="info",
            )
        )
nest_asyncio.apply()
thread = server.start_in_thread()
# Out:
# INFO:     Started server process [115518]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8190 (Press CTRL+C to quit)
# FunmanWorker starting...
# INFO:     127.0.0.1:35712 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42272 - "GET /openapi.json HTTP/1.1" 200 OK
# WARNING: Running without API token
# Starting work on: d225b8ee-970d-41c5-ad63-54727ee40865INFO:     127.0.0.1:60000 - "POST /queries HTTP/1.1" 200 OK
#
# +++ True(Box({'beta': {'lb': 0.0002603, 'ub': 0.0002803}, 'gamma': {'lb': 0.1, 'ub': 0.18}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 0.07999999999999999)
# Completed work on: d225b8ee-970d-41c5-ad63-54727ee40865
# WARNING: Running without API token
# INFO:     127.0.0.1:47508 - "GET /queries/d225b8ee-970d-41c5-ad63-54727ee40865 HTTP/1.1" 200 OK
# WARNING: Running without API token
# Starting work on: b4498815-2142-427e-b309-8fa360d7c7e7
# INFO:     127.0.0.1:40702 - "POST /queries HTTP/1.1" 200 OK
# --- False(Box({'beta': {'lb': 0.00026030000000000004, 'ub': 0.0004}, 'gamma': {'lb': 0.0999, 'ub': 0.1}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 0.00013969999999999998)
# Completed work on: b4498815-2142-427e-b309-8fa360d7c7e7
# WARNING: Running without API token
# Starting work on: ae623713-e352-4926-8f3b-417e47dbd2e1
# INFO:     127.0.0.1:41432 - "POST /queries HTTP/1.1" 200 OK
# +++ True(Box({'beta': {'lb': 0.00026030000000000004, 'ub': 0.0004}, 'gamma': {'lb': 0.0999, 'ub': 0.1}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 0.00013969999999999998)
# Completed work on: ae623713-e352-4926-8f3b-417e47dbd2e1
# WARNING: Running without API token
# Starting work on: 6009cafc-9596-4063-adcf-b3af94576f9c
# INFO:     127.0.0.1:32960 - "POST /queries HTTP/1.1" 200 OK
# --- False(Box({'beta': {'lb': 0.00026030000000000004, 'ub': 0.0004}, 'gamma': {'lb': 0.0999, 'ub': 0.1}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 0.00013969999999999998)
# Completed work on: 6009cafc-9596-4063-adcf-b3af94576f9c
# WARNING: Running without API token
# Starting work on: 962906a7-96eb-4d40-96e8-946711c54a5f
# INFO:     127.0.0.1:36108 - "POST /queries HTTP/1.1" 200 OK
# Split(Box({'beta': {'lb': 0.00026030000000000004, 'ub': 0.0004}, 'gamma': {'lb': 0.0999, 'ub': 0.1}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 0.00013969999999999998)
# --- False(Box({'beta': {'lb': 0.00033015000000000003, 'ub': 0.0004}, 'gamma': {'lb': 0.0999, 'ub': 0.1}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 0.00010000000000000286)
# Split(Box({'beta': {'lb': 0.00026030000000000004, 'ub': 0.00033015000000000003}, 'gamma': {'lb': 0.0999, 'ub': 0.1}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 0.00010000000000000286)
# +++ True(Box({'beta': {'lb': 0.00026030000000000004, 'ub': 0.00033015000000000003}, 'gamma': {'lb': 0.09995000000000001, 'ub': 0.1}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 6.984999999999999e-05)
# Split(Box({'beta': {'lb': 0.00026030000000000004, 'ub': 0.00033015000000000003}, 'gamma': {'lb': 0.0999, 'ub': 0.09995000000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 6.984999999999999e-05)
# Split(Box({'beta': {'lb': 0.00029522500000000003, 'ub': 0.00033015000000000003}, 'gamma': {'lb': 0.0999, 'ub': 0.09995000000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 5.000000000000837e-05)
# --- False(Box({'beta': {'lb': 0.00026030000000000004, 'ub': 0.00029522500000000003}, 'gamma': {'lb': 0.0999, 'ub': 0.09995000000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 5.000000000000837e-05)
# Split(Box({'beta': {'lb': 0.00029522500000000003, 'ub': 0.00033015000000000003}, 'gamma': {'lb': 0.09992500000000001, 'ub': 0.09995000000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 3.4924999999999995e-05)
# WARNING: Running without API token
# INFO:     127.0.0.1:51644 - "GET /queries/962906a7-96eb-4d40-96e8-946711c54a5f HTTP/1.1" 200 OK
# +++ True(Box({'beta': {'lb': 0.00029522500000000003, 'ub': 0.00033015000000000003}, 'gamma': {'lb': 0.0999, 'ub': 0.09992500000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 3.4924999999999995e-05)
# Split(Box({'beta': {'lb': 0.00031268750000000003, 'ub': 0.00033015000000000003}, 'gamma': {'lb': 0.09992500000000001, 'ub': 0.09995000000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 2.4999999999997247e-05)
# +++ True(Box({'beta': {'lb': 0.00029522500000000003, 'ub': 0.00031268750000000003}, 'gamma': {'lb': 0.09992500000000001, 'ub': 0.09995000000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 2.4999999999997247e-05)
# WARNING: Running without API token
# INFO:     127.0.0.1:34866 - "GET /queries/962906a7-96eb-4d40-96e8-946711c54a5f HTTP/1.1" 200 OK
# Split(Box({'beta': {'lb': 0.00031268750000000003, 'ub': 0.00033015000000000003}, 'gamma': {'lb': 0.09993750000000001, 'ub': 0.09995000000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 1.7462499999999998e-05)
# --- False(Box({'beta': {'lb': 0.00031268750000000003, 'ub': 0.00033015000000000003}, 'gamma': {'lb': 0.09992500000000001, 'ub': 0.09993750000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 1.7462499999999998e-05)
# Split(Box({'beta': {'lb': 0.00032141875000000006, 'ub': 0.00033015000000000003}, 'gamma': {'lb': 0.09993750000000001, 'ub': 0.09995000000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 1.2499999999998623e-05)
# +++ True(Box({'beta': {'lb': 0.00031268750000000003, 'ub': 0.00032141875000000006}, 'gamma': {'lb': 0.09993750000000001, 'ub': 0.09995000000000001}, 'S0': {'lb': 1000.0, 'ub': 1000.0}, 'I0': {'lb': 1.0, 'ub': 1.0}, 'R0': {'lb': 0.0, 'ub': 0.0}, 'num_steps': {'lb': 5.0, 'ub': 5.0}, 'step_size': {'lb': 10.0, 'ub': 10.0}}), width = 1.2499999999998623e-05)
# Completed work on: 962906a7-96eb-4d40-96e8-946711c54a5f
# WARNING: Running without API token
# Starting work on: afef91f3-ce62-480b-9dc4-8eb78c824bce
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 1, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 61.69533727906715,
#     "R0": 0.0,
#     "S_1": 500.5,
#     "\u03b2": 0.49863283727906715,
#     "R_0": 0.0,
#     "\u03b3": 437.93750000000006,
#     "R_1": 437.93750000000006
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 2, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.4999999999999,
#     "\u03b2": 0.4995,
#     "S_2": 500.49999999999983,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "\u03b3": 500.4999999999999,
#     "R_1": 500.4999999999999,
#     "R_2": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 3, 'step_size': 1}
# INFO:     127.0.0.1:41548 - "POST /queries HTTP/1.1" 200 OK
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_3": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.2499999999999,
#     "\u03b2": 0.4997499999999999,
#     "S_2": 500.24999999999983,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "\u03b3": 500.74999999999994,
#     "R_2": 500.75,
#     "R_1": 500.74999999999994,
#     "R_3": 500.75,
#     "S_3": 500.2499999999998
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 4, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_3": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.2499999999999,
#     "\u03b2": 0.4997499999999999,
#     "S_2": 500.24999999999983,
#     "R_0": 0.0,
#     "S_3": 500.2499999999998,
#     "\u03b3": 500.74999999999994,
#     "I_2": 0.0,
#     "R_2": 500.75,
#     "R_1": 500.74999999999994,
#     "R_4": 500.75,
#     "S_4": 500.2499999999997,
#     "R_3": 500.75
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 5, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.49999999999994,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.49999999999983,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.4999999999999,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.4999999999998,
#     "S_1": 500.5,
#     "\u03b2": 0.4994999999999998,
#     "\u03b3": 500.4999999999998,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 6, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.49999999999983,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 7, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.4999999999998,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.49999999999983,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 8, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 9, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.24999999999994,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.24999999999994,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.24999999999994,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.24999999999994,
#     "S_7": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.24999999999994,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.24999999999994,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.24999999999994,
#     "S_1": 500.5,
#     "\u03b2": 0.49925,
#     "\u03b3": 500.24999999999994,
#     "I_8": 0.0,
#     "R_8": 500.24999999999994,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.24999999999994,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 10, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_10": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# Completed work on: afef91f3-ce62-480b-9dc4-8eb78c824bce
# WARNING: Running without API token
# INFO:     127.0.0.1:52454 - "GET /queries/afef91f3-ce62-480b-9dc4-8eb78c824bce HTTP/1.1" 200 OK
# WARNING: Running without API token
# INFO:     127.0.0.1:57138 - "GET /queries/afef91f3-ce62-480b-9dc4-8eb78c824bce HTTP/1.1" 200 OK
# WARNING: Running without API token
# INFO:     127.0.0.1:35002 - "GET /queries/afef91f3-ce62-480b-9dc4-8eb78c824bce HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40950 - "GET /openapi.json HTTP/1.1" 200 OK
# WARNING: Running without API token
# Starting work on: 8abde9ae-0d78-4dd0-a6cd-91e32080c5c0
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 1, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 125.12500000000001,
#     "R0": 0.0,
#     "S_1": 625.13623046875,
#     "\u03b2": 0.374619384765625,
#     "R_0": 0.0,
#     "\u03b3": 250.49438476562506,
#     "R_1": 250.49438476562506
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 2, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: null
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 3, 'step_size': 1}
# INFO:     127.0.0.1:40768 - "POST /queries HTTP/1.1" 200 OK
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_3": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.2499999999999,
#     "\u03b2": 0.4997499999999999,
#     "S_2": 500.24999999999983,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "\u03b3": 500.74999999999994,
#     "R_2": 500.75,
#     "R_1": 500.74999999999994,
#     "R_3": 500.75,
#     "S_3": 500.2499999999998
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 4, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_3": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.2499999999999,
#     "\u03b2": 0.4997499999999999,
#     "S_2": 500.24999999999983,
#     "R_0": 0.0,
#     "S_3": 500.2499999999998,
#     "\u03b3": 500.74999999999994,
#     "I_2": 0.0,
#     "R_2": 500.75,
#     "R_1": 500.74999999999994,
#     "R_4": 500.75,
#     "S_4": 500.2499999999997,
#     "R_3": 500.75
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 5, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.49999999999994,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.49999999999983,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.4999999999999,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.4999999999998,
#     "S_1": 500.5,
#     "\u03b2": 0.4994999999999998,
#     "\u03b3": 500.4999999999998,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 6, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.49999999999983,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 7, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.4999999999998,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.49999999999983,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 8, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 9, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 10, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_10": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# Completed work on: 8abde9ae-0d78-4dd0-a6cd-91e32080c5c0
# WARNING: Running without API token
# INFO:     127.0.0.1:40784 - "GET /queries/8abde9ae-0d78-4dd0-a6cd-91e32080c5c0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40856 - "GET /openapi.json HTTP/1.1" 200 OK
# WARNING: Running without API token
# Starting work on: 81918b3e-8e12-4119-b46a-8715e7aa8df3
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 1, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 63.55903432824684,
#     "R0": 0.0,
#     "S_1": 11.74252569908291,
#     "\u03b2": 0.9876083423967141,
#     "R_0": 0.0,
#     "\u03b3": 925.0493080684674,
#     "R_1": 925.0493080684674
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 2, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.4999999999999,
#     "\u03b2": 0.4995,
#     "S_2": 500.49999999999983,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "\u03b3": 500.4999999999999,
#     "R_1": 500.4999999999999,
#     "R_2": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 3, 'step_size': 1}
# INFO:     127.0.0.1:34900 - "POST /queries HTTP/1.1" 200 OK
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_3": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.2499999999999,
#     "\u03b2": 0.4997499999999999,
#     "S_2": 500.24999999999983,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "\u03b3": 500.74999999999994,
#     "R_2": 500.75,
#     "R_1": 500.74999999999994,
#     "R_3": 500.75,
#     "S_3": 500.2499999999998
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 4, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_3": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.2499999999999,
#     "\u03b2": 0.4997499999999999,
#     "S_2": 500.24999999999983,
#     "R_0": 0.0,
#     "S_3": 500.2499999999998,
#     "\u03b3": 500.74999999999994,
#     "I_2": 0.0,
#     "R_2": 500.75,
#     "R_1": 500.74999999999994,
#     "R_4": 500.75,
#     "S_4": 500.2499999999997,
#     "R_3": 500.75
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 5, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.49999999999994,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.49999999999983,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.4999999999999,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.4999999999998,
#     "S_1": 500.5,
#     "\u03b2": 0.4994999999999998,
#     "\u03b3": 500.4999999999998,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 6, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.49999999999983,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 7, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.4999999999998,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.49999999999983,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 8, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 9, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 10, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.49999999999994,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_10": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.4999999999999,
#     "S_1": 500.5,
#     "\u03b2": 0.49949999999999983,
#     "\u03b3": 500.4999999999999,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# Completed work on: 81918b3e-8e12-4119-b46a-8715e7aa8df3
# WARNING: Running without API token
# INFO:     127.0.0.1:47378 - "GET /queries/81918b3e-8e12-4119-b46a-8715e7aa8df3 HTTP/1.1" 200 OK
# WARNING: Running without API token
# Starting work on: 555a638c-3006-4952-a8dc-df13af5136a7
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 2, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.4999999999999,
#     "\u03b2": 0.4995,
#     "S_2": 500.49999999999983,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "\u03b3": 500.4999999999999,
#     "R_1": 500.4999999999999,
#     "R_2": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 3, 'step_size': 1}
# INFO:     127.0.0.1:40380 - "POST /queries HTTP/1.1" 200 OK
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_3": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.2499999999999,
#     "\u03b2": 0.4997499999999999,
#     "S_2": 500.24999999999983,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "\u03b3": 500.74999999999994,
#     "R_2": 500.75,
#     "R_1": 500.74999999999994,
#     "R_3": 500.75,
#     "S_3": 500.2499999999998
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 4, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_3": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.2499999999999,
#     "\u03b2": 0.4997499999999999,
#     "S_2": 500.24999999999983,
#     "R_0": 0.0,
#     "S_3": 500.2499999999998,
#     "\u03b3": 500.74999999999994,
#     "I_2": 0.0,
#     "R_2": 500.75,
#     "R_1": 500.74999999999994,
#     "R_4": 500.75,
#     "S_4": 500.2499999999997,
#     "R_3": 500.75
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 5, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.49999999999994,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.49999999999983,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.4999999999999,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.4999999999998,
#     "S_1": 500.5,
#     "\u03b2": 0.4994999999999998,
#     "\u03b3": 500.4999999999998,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 6, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.49999999999983,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 7, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.4999999999998,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.49999999999983,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 8, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 9, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 10, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_4": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_4": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_7": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_10": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 11, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_11": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_11": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_7": 500.5,
#     "R_4": 500.5,
#     "S_4": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_11": 0.0,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 12, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_11": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "S_11": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_7": 500.5,
#     "R_4": 500.5,
#     "S_4": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_11": 0.0,
#     "I_12": 0.0,
#     "R_12": 500.5,
#     "S_12": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 13, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_11": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_11": 0.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_11": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_7": 500.5,
#     "R_4": 500.5,
#     "S_4": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_12": 0.0,
#     "R_12": 500.5,
#     "S_12": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "I_13": 0.0,
#     "R_13": 500.5,
#     "S_13": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 14, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_11": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_11": 0.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_11": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_7": 500.5,
#     "R_4": 500.5,
#     "I_14": 0.0,
#     "S_4": 500.5,
#     "R_14": 500.5,
#     "S_14": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_12": 0.0,
#     "R_12": 500.5,
#     "S_12": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "I_13": 0.0,
#     "R_13": 500.5,
#     "S_13": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 15, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_11": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_11": 0.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_11": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_7": 500.5,
#     "R_4": 500.5,
#     "I_14": 0.0,
#     "S_4": 500.5,
#     "R_14": 500.5,
#     "S_14": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_12": 0.0,
#     "R_12": 500.5,
#     "S_12": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "I_13": 0.0,
#     "R_13": 500.5,
#     "S_13": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 16, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_11": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_11": 0.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_11": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_16": 0.0,
#     "R_16": 500.5,
#     "S_16": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_7": 500.5,
#     "R_4": 500.5,
#     "I_14": 0.0,
#     "S_4": 500.5,
#     "R_14": 500.5,
#     "S_14": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_12": 0.0,
#     "R_12": 500.5,
#     "S_12": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "I_13": 0.0,
#     "R_13": 500.5,
#     "S_13": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 17, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "R_11": 500.5,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_11": 0.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_11": 500.5,
#     "S_2": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_16": 0.0,
#     "R_16": 500.5,
#     "S_16": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_7": 500.5,
#     "R_4": 500.5,
#     "I_14": 0.0,
#     "S_4": 500.5,
#     "R_14": 500.5,
#     "S_14": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_12": 0.0,
#     "R_12": 500.5,
#     "S_12": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_17": 0.0,
#     "R_17": 500.5,
#     "S_17": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "I_13": 0.0,
#     "R_13": 500.5,
#     "S_13": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 18, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_11": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R_11": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "S_11": 500.5,
#     "I_18": 0.0,
#     "R_18": 500.5,
#     "S_18": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_16": 0.0,
#     "R_16": 500.5,
#     "S_16": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_7": 500.5,
#     "R_4": 500.5,
#     "I_14": 0.0,
#     "S_4": 500.5,
#     "R_14": 500.5,
#     "S_14": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_12": 0.0,
#     "R_12": 500.5,
#     "S_12": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_17": 0.0,
#     "R_17": 500.5,
#     "S_17": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "I_13": 0.0,
#     "R_13": 500.5,
#     "S_13": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 19, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_11": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R_11": 500.5,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.5,
#     "S_2": 500.5,
#     "S_11": 500.5,
#     "I_16": 0.0,
#     "R_16": 500.5,
#     "S_16": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "S_7": 500.5,
#     "I_12": 0.0,
#     "R_12": 500.5,
#     "S_12": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.5,
#     "S_3": 500.5,
#     "I_17": 0.0,
#     "R_17": 500.5,
#     "S_17": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.5,
#     "S_8": 500.5,
#     "I_13": 0.0,
#     "R_13": 500.5,
#     "S_13": 500.5,
#     "I_4": 0.0,
#     "R_4": 500.5,
#     "S_4": 500.5,
#     "I_18": 0.0,
#     "R_18": 500.5,
#     "S_18": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.5,
#     "S_9": 500.5,
#     "I_14": 0.0,
#     "R_14": 500.5,
#     "S_14": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_19": 0.0,
#     "R_19": 500.5,
#     "S_19": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.5,
#     "S_1": 500.5,
#     "\u03b2": 0.4995,
#     "\u03b3": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.5,
#     "S_6": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 20, 'step_size': 1}
# WARNING: Running without API token
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_11": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R_11": 500.49999999999994,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "R_2": 500.49999999999943,
#     "S_2": 500.5,
#     "S_11": 500.5,
#     "I_16": 0.0,
#     "R_16": 500.5,
#     "S_16": 500.5,
#     "I_7": 0.0,
#     "R_7": 500.4999999999997,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.4999999999999,
#     "S_7": 500.5,
#     "I_12": 0.0,
#     "R_12": 500.5,
#     "S_12": 500.5,
#     "I_3": 0.0,
#     "R_3": 500.4999999999995,
#     "S_3": 500.5,
#     "S_20": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "I_17": 0.0,
#     "R_17": 500.5,
#     "S_17": 500.5,
#     "I_8": 0.0,
#     "R_8": 500.4999999999998,
#     "S_8": 500.5,
#     "I_13": 0.0,
#     "R_13": 500.5,
#     "S_13": 500.5,
#     "I_4": 0.0,
#     "R_4": 500.49999999999955,
#     "S_4": 500.5,
#     "I_18": 0.0,
#     "R_18": 500.5,
#     "S_18": 500.5,
#     "I_9": 0.0,
#     "R_9": 500.49999999999983,
#     "S_9": 500.5,
#     "I_14": 0.0,
#     "R_14": 500.5,
#     "S_14": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.4999999999996,
#     "S_5": 500.5,
#     "I_19": 0.0,
#     "R_19": 500.5,
#     "S_19": 500.5,
#     "I_1": 0.0,
#     "R_1": 500.4999999999994,
#     "S_1": 500.5,
#     "\u03b2": 0.49949999999999933,
#     "\u03b3": 500.4999999999994,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "I_6": 0.0,
#     "R_6": 500.49999999999966,
#     "S_6": 500.5
# }
# Completed work on: 555a638c-3006-4952-a8dc-df13af5136a7
# INFO:     127.0.0.1:35906 - "GET /queries/555a638c-3006-4952-a8dc-df13af5136a7 HTTP/1.1" 200 OK
# WARNING: Running without API token
# Starting work on: ebd59644-ef2e-419b-ba47-6b86bd7ce07e
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 2, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.4999999999999,
#     "\u03b2": 0.4995,
#     "S_2": 500.49999999999983,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "\u03b3": 500.4999999999999,
#     "R_1": 500.4999999999999,
#     "R_2": 500.4999999999999
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 3, 'step_size': 1}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_3": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.2499999999999,
#     "\u03b2": 0.4997499999999999,
#     "S_2": 500.24999999999983,
#     "R_0": 0.0,
#     "I_2": 0.0,
#     "\u03b3": 500.74999999999994,
#     "R_2": 500.75,
#     "R_1": 500.74999999999994,
#     "R_3": 500.75,
#     "S_3": 500.2499999999998
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 4, 'step_size': 1}
# INFO:     127.0.0.1:35880 - "POST /queries HTTP/1.1" 200 OK
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_4": 0.0,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I_3": 0.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "I_1": 0.0,
#     "R0": 0.0,
#     "S_1": 500.2499999999999,
#     "\u03b2": 0.4997499999999999,
#     "S_2": 500.24999999999983,
# ...
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "\u03b2": 0.09989999999999996,
#     "\u03b3": 100.09999999999997,
#     "S_20": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.49999999999994,
#     "S_15": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.4999999999999,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.49999999999983,
#     "S_5": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 7, 'step_size': 5}
# WARNING: Running without API token
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "\u03b2": 0.09989999999999996,
#     "\u03b3": 100.09999999999994,
#     "S_20": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.49999999999966,
#     "I_35": 0.0,
#     "R_35": 500.49999999999966,
#     "S_35": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.49999999999966,
#     "S_25": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.49999999999966,
#     "S_15": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.49999999999966,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.49999999999966,
#     "I_5": 0.0,
#     "R_5": 500.49999999999966,
#     "S_5": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 8, 'step_size': 5}
# INFO:     127.0.0.1:37320 - "GET /queries/adf8b084-a9aa-4414-ade8-b3503391d13e HTTP/1.1" 200 OK
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "S_40": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "\u03b2": 0.09989999999999999,
#     "\u03b3": 100.1,
#     "I_35": 0.0,
#     "S_35": 500.5,
#     "R_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 9, 'step_size': 5}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "S_40": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_45": 0.0,
#     "R_45": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "S_45": 500.49999999999994,
#     "\u03b2": 0.09989999999999999,
#     "\u03b3": 100.1,
#     "I_35": 0.0,
#     "S_35": 500.5,
#     "R_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 10, 'step_size': 5}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "S_40": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_45": 0.0,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "R_45": 500.5,
#     "S_45": 500.5,
#     "S_5": 500.5,
#     "\u03b2": 0.09989999999999999,
#     "\u03b3": 100.1,
#     "I_35": 0.0,
#     "S_35": 500.5,
#     "R_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 11, 'step_size': 5}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "S_40": 500.5,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "I_55": 0.0,
#     "R_55": 500.5,
#     "S_55": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_45": 0.0,
#     "I_5": 0.0,
#     "R_45": 500.5,
#     "S_45": 500.5,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "\u03b2": 0.09989999999999999,
#     "I_35": 0.0,
#     "R_35": 500.5,
#     "S_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "\u03b3": 100.1,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 12, 'step_size': 5}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "S_40": 500.5,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "I_55": 0.0,
#     "R_55": 500.5,
#     "S_55": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_45": 0.0,
#     "R_45": 500.5,
#     "S_45": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "\u03b2": 0.09989999999999999,
#     "I_35": 0.0,
#     "R_35": 500.5,
#     "S_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "\u03b3": 100.1,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_60": 0.0,
#     "R_60": 500.5,
#     "S_60": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 13, 'step_size': 5}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "S_40": 500.5,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "I_65": 0.0,
#     "R_65": 500.5,
#     "S_65": 500.5,
#     "I_55": 0.0,
#     "R_55": 500.5,
#     "S_55": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_45": 0.0,
#     "R_45": 500.5,
#     "S_45": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "\u03b2": 0.09989999999999999,
#     "I_35": 0.0,
#     "R_35": 500.5,
#     "S_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "\u03b3": 100.1,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_60": 0.0,
#     "R_60": 500.5,
#     "S_60": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 14, 'step_size': 5}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "S_40": 500.5,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "I_65": 0.0,
#     "R_65": 500.5,
#     "S_65": 500.5,
#     "I_55": 0.0,
#     "R_55": 500.5,
#     "S_55": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_45": 0.0,
#     "R_45": 500.5,
#     "S_45": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "\u03b2": 0.09989999999999999,
#     "I_35": 0.0,
#     "R_35": 500.5,
#     "S_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "\u03b3": 100.1,
#     "I_70": 0.0,
#     "R_70": 500.5,
#     "S_70": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_60": 0.0,
#     "R_60": 500.5,
#     "S_60": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 15, 'step_size': 5}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "S_40": 500.5,
#     "I_75": 0.0,
#     "R_75": 500.5,
#     "S_75": 500.5,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "I_65": 0.0,
#     "R_65": 500.5,
#     "S_65": 500.5,
#     "I_55": 0.0,
#     "R_55": 500.5,
#     "S_55": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_45": 0.0,
#     "R_45": 500.5,
#     "S_45": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "\u03b2": 0.09989999999999999,
#     "I_35": 0.0,
#     "R_35": 500.5,
#     "S_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "\u03b3": 100.1,
#     "I_70": 0.0,
#     "R_70": 500.5,
#     "S_70": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_60": 0.0,
#     "R_60": 500.5,
#     "S_60": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 16, 'step_size': 5}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "S_40": 500.5,
#     "I_75": 0.0,
#     "R_75": 500.5,
#     "S_75": 500.5,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "I_65": 0.0,
#     "R_65": 500.5,
#     "S_65": 500.5,
#     "I_55": 0.0,
#     "R_55": 500.5,
#     "S_55": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_45": 0.0,
#     "R_45": 500.5,
#     "S_45": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_80": 0.0,
#     "R_80": 500.5,
#     "S_80": 500.5,
#     "\u03b2": 0.09989999999999999,
#     "I_35": 0.0,
#     "R_35": 500.5,
#     "S_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "\u03b3": 100.1,
#     "I_70": 0.0,
#     "R_70": 500.5,
#     "S_70": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_60": 0.0,
#     "R_60": 500.5,
#     "S_60": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 17, 'step_size': 5}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_85": 0.0,
#     "R_85": 500.5,
#     "S_85": 500.5,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "S_40": 500.5,
#     "I_75": 0.0,
#     "R_75": 500.5,
#     "S_75": 500.5,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "I_65": 0.0,
#     "R_65": 500.5,
#     "S_65": 500.5,
#     "I_55": 0.0,
#     "R_55": 500.5,
#     "S_55": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_45": 0.0,
#     "R_45": 500.5,
#     "S_45": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_80": 0.0,
#     "R_80": 500.5,
#     "S_80": 500.5,
#     "\u03b2": 0.09989999999999999,
#     "I_35": 0.0,
#     "R_35": 500.5,
#     "S_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "\u03b3": 100.1,
#     "I_70": 0.0,
#     "R_70": 500.5,
#     "S_70": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_60": 0.0,
#     "R_60": 500.5,
#     "S_60": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 18, 'step_size': 5}
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "I_85": 0.0,
#     "R_85": 500.5,
#     "S_85": 500.5,
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "S_40": 500.5,
#     "I_75": 0.0,
#     "R_75": 500.5,
#     "S_75": 500.5,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "I_65": 0.0,
#     "R_65": 500.5,
#     "S_65": 500.5,
#     "I_55": 0.0,
#     "R_55": 500.5,
#     "S_55": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_45": 0.0,
#     "R_45": 500.5,
#     "S_45": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.5,
#     "S_5": 500.5,
#     "I_90": 0.0,
#     "R_90": 500.5,
#     "S_90": 500.5,
#     "I_80": 0.0,
#     "R_80": 500.5,
#     "S_80": 500.5,
#     "\u03b2": 0.09989999999999999,
#     "I_35": 0.0,
#     "R_35": 500.5,
#     "S_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "\u03b3": 100.1,
#     "I_70": 0.0,
#     "R_70": 500.5,
#     "S_70": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_60": 0.0,
#     "R_60": 500.5,
#     "S_60": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 19, 'step_size': 5}
# WARNING: Running without API token
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_75": 0.0,
#     "R_75": 500.5,
#     "S_75": 500.5,
#     "I_55": 0.0,
#     "R_55": 500.5,
#     "S_55": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.5,
#     "I_80": 0.0,
#     "R_80": 500.5,
#     "S_80": 500.5,
#     "I_35": 0.0,
#     "R_35": 500.5,
#     "S_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.5,
#     "S_20": 500.5,
#     "I_60": 0.0,
#     "R_60": 500.5,
#     "S_60": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.5,
#     "I_85": 0.0,
#     "R_85": 500.5,
#     "S_85": 500.5,
#     "S_40": 500.5,
#     "I_40": 0.0,
#     "R_40": 500.5,
#     "I_65": 0.0,
#     "R_65": 500.5,
#     "S_65": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.5,
#     "I_45": 0.0,
#     "I_90": 0.0,
#     "S_45": 500.5,
#     "R_45": 500.5,
#     "R_90": 500.5,
#     "S_90": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.49999999999994,
#     "S_5": 500.5,
#     "\u03b2": 0.09989999999999997,
#     "\u03b3": 100.09999999999998,
#     "I_70": 0.0,
#     "R_70": 500.5,
#     "S_70": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.5,
#     "S_25": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.5,
#     "S_15": 500.5,
#     "I_95": 0.0,
#     "R_95": 500.5,
#     "S_95": 500.5
# }
# INFO:/root/funman/src/funman/search/smt_check.py:Solving configuration: {'num_steps': 20, 'step_size': 5}
# INFO:     127.0.0.1:44616 - "GET /queries/adf8b084-a9aa-4414-ade8-b3503391d13e HTTP/1.1" 200 OK
# INFO:/root/funman/src/funman/search/smt_check.py:Result: {
#     "S0": 1000.0,
#     "S_0": 1000.0,
#     "I0": 1.0,
#     "I_0": 1.0,
#     "R0": 0.0,
#     "R_0": 0.0,
#     "I_75": 0.0,
#     "R_75": 500.5,
#     "S_75": 500.5,
#     "I_55": 0.0,
#     "R_55": 500.5,
#     "S_55": 500.5,
#     "S_10": 500.5,
#     "I_10": 0.0,
#     "R_10": 500.4999999999995,
#     "I_100": 0.0,
#     "R_100": 500.5,
#     "S_100": 500.5,
#     "I_80": 0.0,
#     "R_80": 500.5,
#     "S_80": 500.5,
#     "I_35": 0.0,
#     "R_35": 500.4999999999998,
#     "S_35": 500.5,
#     "I_20": 0.0,
#     "R_20": 500.4999999999996,
#     "S_20": 500.5,
#     "I_60": 0.0,
#     "R_60": 500.5,
#     "S_60": 500.5,
#     "S_30": 500.5,
#     "I_30": 0.0,
#     "R_30": 500.4999999999997,
#     "I_85": 0.0,
#     "R_85": 500.5,
#     "S_85": 500.5,
#     "S_40": 500.5,
#     "I_40": 0.0,
#     "R_40": 500.49999999999983,
#     "I_65": 0.0,
#     "R_65": 500.5,
#     "S_65": 500.5,
#     "S_50": 500.5,
#     "I_50": 0.0,
#     "R_50": 500.49999999999994,
#     "I_45": 0.0,
#     "I_90": 0.0,
#     "S_45": 500.5,
#     "R_45": 500.4999999999999,
#     "R_90": 500.5,
#     "S_90": 500.5,
#     "I_5": 0.0,
#     "R_5": 500.49999999999943,
#     "S_5": 500.5,
#     "\u03b2": 0.09989999999999988,
#     "\u03b3": 100.09999999999988,
#     "I_70": 0.0,
#     "R_70": 500.5,
#     "S_70": 500.5,
#     "I_25": 0.0,
#     "R_25": 500.49999999999966,
#     "S_25": 500.5,
#     "I_15": 0.0,
#     "R_15": 500.49999999999955,
#     "S_15": 500.5,
#     "I_95": 0.0,
#     "R_95": 500.5,
#     "S_95": 500.5
# }
# Completed work on: adf8b084-a9aa-4414-ade8-b3503391d13e

# %%
# Close out server
server.should_exit = True
thread.join()
